# %%
import os
from dotenv import load_dotenv
load_dotenv()

# Initialise environment variables
GOOGLE_API_KEY=os.environ.get("GOOGLE_API_KEY")
print(os.environ.get("GOOGLE_API_KEY"))
# Out:
# AIzaSyCeNl-5S41xPWOqag6ryiI23QVt_0pAag4

# %%
import google.generativeai as genai
# from google import genai

# %%
def get_completion(prompt, model="gemini-2.5-flash"):
    model = genai.GenerativeModel(model,generation_config=genai.GenerationConfig(temperature=0))
    response = model.generate_content(prompt)
    return response.text

# %%
from IPython.display import Markdown,display

response = get_completion(prompt="explain genai in 2 bullet points")

display(Markdown(response))
# Out:
# Here are two bullet points explaining Generative AI (GenAI):
#
# *   **GenAI is a type of artificial intelligence that *creates* original, novel content** (like text, images, code, or audio) rather than just analyzing or classifying existing data.
# *   **It learns complex patterns and structures from vast datasets,** enabling it to generate new, coherent, and often human-like outputs in response to prompts or instructions.

# %%
# check all models for gemini

# from google import genai

# genai = genai.Client(api_key=GOOGLE_API_KEY)

# models = genai.models.list()

# for model in models:
#     print(f"Model Name: {model.name}")
#     print(f"Display Name: {model.display_name}")
#     print(f"Input Token Limit: {model.input_token_limit}")
#     print("-" * 30)

# %%
def get_completion_image(prompt, img_1, img_2, model="gemini-2.5-flash"):
    model = genai.GenerativeModel(model,generation_config=genai.GenerationConfig(temperature=0))
    response = model.generate_content([prompt, img_1, img_2])
    return response.text

# %%
from IPython.display import Image
from IPython.core.display import HTML

img_path1 = r"image_path"
img_path2 = r"image_path"

img_1 = Image(img_path1)
img_2 = Image(img_path2)

display(img_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# FileNotFoundError: No such file or directory: 'image_path'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# FileNotFoundError: No such file or directory: 'image_path'

# %%
prompt = """
Given The Following Images which can contains graph, tables and text,
analyse all of them to answer the following question

"""
